# %% [markdown]
# ## Model Training and Model Evaluation

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("cleaned_dataset.csv")
df
# Out:
#        gender  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  active  \
# 0           2    62.0    110     80            1     1      0     0       1
# 1           1    85.0    140     90            3     1      0     0       1
# 2           1    64.0    130     70            3     1      0     0       0
# 3           2    82.0    150    100            1     1      0     0       1
# 4           1    56.0    100     60            1     1      0     0       0
# ...       ...     ...    ...    ...          ...   ...    ...   ...     ...
# 69971       2    76.0    120     80            1     1      1     0       1
# 69972       1   126.0    140     90            2     2      0     0       1
# 69973       2   105.0    180     90            3     1      0     1       0
# 69974       1    72.0    135     80            1     2      0     0       0
# 69975       1    72.0    120     80            2     1      0     0       1
#
#        age_years        bmi  pulse_pressure  health_index  cardio
# 0             50  21.967120              30             0       0
# 1             55  34.927679              50             1       1
# 2             51  23.507805              60             2       1
# 3             48  28.710479              50             0       1
# 4             47  23.011177              40             1       0
# ...          ...        ...             ...           ...     ...
# 69971         52  26.927438              40             1       0
# 69972         61  50.472681              50             2       1
# 69973         52  31.353579              90             3       1
# 69974         61  27.099251              55             2       1
# 69975         56  24.913495              40             1       0
#
# [69976 rows x 14 columns]

# %%
target = 'cardio'
features = [col for col in df.columns if col != target]

# %%
X = df[features]
y = df[target]
X.shape, y.shape
# Out:
# ((69976, 13), (69976,))

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.1,
    random_state=27,
    stratify=y
)

# %%
rf = RandomForestClassifier(
    n_estimators=100,
    random_state=27
)

# %%
rf.fit(X_train, y_train,)
# Out:
# RandomForestClassifier(random_state=27)

# %%
y_pred = rf.predict(X_test)
y_pred[:10]
# Out:
# array([1, 0, 0, 0, 0, 0, 1, 1, 0, 1])

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy : {accuracy:.2f}")
# Out:
# Accuracy : 0.70

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[2486, 1015],
#        [1091, 2406]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.71      0.70      3501
#            1       0.70      0.69      0.70      3497
#
#     accuracy                           0.70      6998
#    macro avg       0.70      0.70      0.70      6998
# weighted avg       0.70      0.70      0.70      6998

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
import pandas as pd

feature_importance = pd.Series(
    rf.feature_importances_,
    index=X.columns
).sort_values(ascending=False)

feature_importance
feature_importance.plot(kind='bar', figsize=(10,4))
# Out:
# <Axes: >

# %% [markdown]
# ## Save the model on disk

# %%
import joblib

feature_order = list(X_train.columns)

joblib.dump(
    {
        'model': rf,
        'columns': feature_order
    },
    'cardio_model.pkl'
)
# Out:
# ['cardio_model.pkl']
